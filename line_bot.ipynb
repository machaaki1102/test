# %%
# !pip install line-bot-sdk
# Out:
# ...
#      |████████████████████████████████| 71kB 4.7MB/s
# ...

# %%
file = {'CHANMEL_ACCESS_TOKIN':'/yqYGcp1lCHB8/aiOZ+ybwT5IE8mtIbphh6M42T0qAG7WQIjWBL5frjnDHeEyZJHhm7biQN4fyNhlw6TdboLSx8pkUMYbIE3JtPqnYMTnTZu5cXYyvDFuF01AajuZ8PS3fp6s1oPUa40vs6vwwUAiQdB04t89/1O/w1cDnyilFU=','USER_ID':'U12291b23c4297867269f533535d3cbbd'}

# %%
file
# Out:
# {'CHANMEL_ACCESS_TOKIN': '/yqYGcp1lCHB8/aiOZ+ybwT5IE8mtIbphh6M42T0qAG7WQIjWBL5frjnDHeEyZJHhm7biQN4fyNhlw6TdboLSx8pkUMYbIE3JtPqnYMTnTZu5cXYyvDFuF01AajuZ8PS3fp6s1oPUa40vs6vwwUAiQdB04t89/1O/w1cDnyilFU=',
#  'USER_ID': 'U12291b23c4297867269f533535d3cbbd'}

# %%
from linebot import LineBotApi
from linebot.models import TextSendMessage

# %%
CHANMEL_ACCESS_TOKIN = file['CHANMEL_ACCESS_TOKIN']

# %%
line_bot_API =  LineBotApi(CHANMEL_ACCESS_TOKIN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-574986077499> in <module>()
# ----> 1 line_bot_API =  LineBotApi(CHANMEL_ACCESS_TOKIN)
#
# NameError: name 'LineBotApi' is not defined

# %%
def main():
    USER_ID = file['USER_ID']
    messages = TextSendMessage(text="おはよう \n 起きて")
    line_bot_API.push_message(USER_ID,messages=messages)

if __name__ == "__main__":
    main()
